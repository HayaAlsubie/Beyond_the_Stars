# %%
import pandas as pd

# %%
N = pd.read_csv("negative_reviews.csv")
N.head()
# Out:
#   Region  City Place Type Place Category      Place Name  Rating  \
# 0  North  Hail      hotel        lodging  Raoum Inn Hail     3.3
# 1  North  Hail      hotel        lodging  Raoum Inn Hail     3.3
# 2  North  Hail      hotel        lodging  Raoum Inn Hail     3.3
# 3  North  Hail      hotel        lodging  Raoum Inn Hail     3.3
# 4  North  Hail      hotel        lodging  Raoum Inn Hail     3.3
#
#                                          Review Text Reviewer Language  \
# 0  The rooms are really good, the only issue is w...                en
# 1  Arrived at hotel\nVery good receptionist\nAnd ...                en
# 2  Great hotel, with nice view and easy outside s...                en
# 3  Absolutely disgusting. I found a hair in the b...                en
# 4  Very Bad Management Not good Sarvice Not Good ...                en
#
#                                       Cleaned Review    neg    neu    pos  \
# ...

# %%
N.to_csv('N.csv', index=False)
